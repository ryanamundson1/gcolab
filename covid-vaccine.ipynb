# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

import os

filename = '/Users/ramundson/Jupyter/data/vaccinations.csv'

df = pd.read_csv(filename)

local_df = df.loc[(df["iso_code"]=="USA")]
local_df.reset_index(drop=True, inplace=True)

local_df = local_df.sort_values(by=["date"])
local_df["new_vac"] = local_df["people_vaccinated"].diff()

local_df["Rolling 7d"] = local_df["daily_vaccinations"].rolling(7).mean()
local_df.tail(31)
# Out:
#          location iso_code        date  total_vaccinations  people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  total_vaccinations_per_hundred  people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  daily_vaccinations_per_million    new_vac     Rolling 7d
# 5   United States      USA  2020-12-25                 NaN                NaN                      NaN                     NaN            215238.0                             NaN                            NaN                                  NaN                           650.0        NaN            NaN
# 6   United States      USA  2020-12-26           1944585.0          1944585.0                      NaN                     NaN            231396.0                            0.59                           0.59                                  NaN                           699.0        NaN            NaN
# ...
